# %%
# *******************************Python For Data Visualisation using Pandas ****************************************
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
#Part 1 - Pandas Built-in Data Visualisation
dates = pd.date_range('1/1/2000', periods = 500)

# %%
col_D = np.random.rand(500)

# %%
data1 = np.random.randn(500,3)

# %%
df1 = pd.DataFrame(data = data1, index = dates, columns = ['A', 'B', 'C'])
df1.head()
# Out:
#                    A         B         C
# 2000-01-01  0.203430  0.162116  2.077157
# 2000-01-02 -0.813277 -1.186265  0.060908
# 2000-01-03  0.663513  0.973125 -1.264087
# 2000-01-04  0.583386  0.951181 -1.650386
# 2000-01-05  1.013011  1.411255 -0.559556

# %%
df1['D'] = col_D
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  0.203430  0.162116  2.077157  0.166800
# 2000-01-02 -0.813277 -1.186265  0.060908  0.154456
# 2000-01-03  0.663513  0.973125 -1.264087  0.830449
# 2000-01-04  0.583386  0.951181 -1.650386  0.192537
# 2000-01-05  1.013011  1.411255 -0.559556  0.647227

# %% [markdown]
# data2 = np.random.rand(20,3)
# col = ['X', 'Y', 'Z']
# df2 = pd.DataFrame(data = data2, columns = col)
# df2.head()

# %%
df1['A'].hist(bins=50)

# %%
df1['A'].plot(kind = 'hist', bins = 50)

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
df1['A'].hist(bins=50)

# %%
plt.style.use('dark_background')
df1['A'].hist(bins=50)

# %%
plt.style.use('fivethirtyeight')
df1['A'].hist(bins=50)

# %%
plt.style.use('ggplot')

# %%
df2.plot(kind = 'area', alpha = 0.5)

# %%
df2.plot.area(alpha = 0.5)

# %%
df2.plot.bar()

# %%
df2.plot.bar(stacked = True)

# %%
df1['A'].plot.hist(bins = 30)

# %%
df1.plot.hist(bins = 30)

# %%
df1.plot.hist(stacked =  True)

# %%
df1.plot.hist(orientation= 'horizontal', alpha = 0.5)

# %%
df1.plot.line(x = df1.index, y = 'B', lw =1, figsize = (12,3))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-fe2e630d571a> in <module>
# ----> 1 df1.plot.line(x = df1.index, y = 'B', lw =1, figsize = (12,3))
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in line(self, x, y, **kwds)
#    3004             >>> lines = df.plot.line(x='pig', y='horse')
#    3005         """
# -> 3006         return self(kind='line', x=x, y=y, **kwds)
#    3007
#    3008     def bar(self, x=None, y=None, **kwds):
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2940                           fontsize=fontsize, colormap=colormap, table=table,
#    2941                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2942                           sort_columns=sort_columns, **kwds)
#    2943     __call__.__doc__ = plot_frame.__doc__
#    2944
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1971                  yerr=yerr, xerr=xerr,
#    1972                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1973                  **kwds)
#    1974
#    1975
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1761                 if is_integer(x) and not data.columns.holds_integer():
#    1762                     x = data_cols[x]
# -> 1763                 elif not isinstance(data[x], ABCSeries):
#    1764                     raise ValueError("x must be a label or position")
#    1765                 data = data.set_index(x)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1355         else:
#    1356             try:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1159         self._validate_read_indexer(keyarr, indexer,
#    1160                                     o._get_axis_number(axis),
# -> 1161                                     raise_missing=raise_missing)
#    1162         return keyarr, indexer
#    1163
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1244                 raise KeyError(
#    1245                     u"None of [{key}] are in the [{axis}]".format(
# -> 1246                         key=key, axis=self.obj._get_axis_name(axis)))
#    1247
#    1248             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',\n               '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08',\n               '2000-01-09', '2000-01-10',\n               ...\n               '2001-05-05', '2001-05-06', '2001-05-07', '2001-05-08',\n               '2001-05-09', '2001-05-10', '2001-05-11', '2001-05-12',\n               '2001-05-13', '2001-05-14'],\n              dtype='datetime64[ns]', length=500, freq='D')] are in the [columns]"

# %%
df1.plot.scatter(x='A', y='B')

# %%
ax = df1.plot.scatter(x='A', y='B', color = 'DarkBlue', label = 'Group1')
df1.plot.scatter(x='C', y='D', color = 'DarkGreen', ax = ax, label = 'Group2')

# %%
df1.plot.scatter(x='A', y='B', c='C', s =50, cmap = 'coolwarm')

# %%
df1.plot.scatter(x='A', y='B', s = df1['C']*100)

# %%
df2.plot.box()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1cc4a2ea7873> in <module>
# ----> 1 df2.plot.box()
#
# NameError: name 'df2' is not defined

# %%
df2.plot.box(vert = False)

# %%
color = dict(boxes = 'DarkGreen', whiskers = 'DarkOrange', medians = 'DarkBlue', caps ='Grey')

# %%
df2.plot.box(color = color)

# %%
df2['group'] = np.random.choice(['A', 'B'], size = 20)

# %%
df2.head()
# Out:
#           X         Y         Z group
# 0  0.052314  0.659137  0.975178     A
# 1  0.480199  0.448812  0.186691     B
# 2  0.040650  0.803181  0.262377     A
# 3  0.300231  0.490325  0.588358     A
# 4  0.767582  0.993762  0.985776     B

# %%
df2.boxplot(column = ['X', 'Y'], by = 'group')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001AE01428EB8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001AE0148C9E8>],
#       dtype=object)

# %%
df2.drop('group', axis = 1, inplace=True)
df2.head()
# Out:
#           X         Y         Z
# 0  0.052314  0.659137  0.975178
# 1  0.480199  0.448812  0.186691
# 2  0.040650  0.803181  0.262377
# 3  0.300231  0.490325  0.588358
# 4  0.767582  0.993762  0.985776

# %%
df1.plot.hexbin(x='A', y='B', gridsize = 25, cmap = 'Oranges')

# %%
df2['X'].plot.kde()

# %%
df2.plot.density()

# %%
df2.plot.pie(y='X', figsize = (4,4), legend = False)

# %%
df2.plot.pie(subplots = True, figsize = (12,4), legend = False)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001AE0358D240>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001AE035B9A90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001AE035E32E8>],
#       dtype=object)
